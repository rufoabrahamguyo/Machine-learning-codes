# %% [markdown]
# <a href="https://colab.research.google.com/github/rufoabrahamguyo/Library-Management-System/blob/main/RandomForestClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer=load_breast_cancer()
X_train,X_test,y_train,y_test=train_test_split(cancer.data,cancer.target,stratify=cancer.target,random_state=42)
model=RandomForestClassifier(n_estimators=100,random_state=0 )
model.fit(X_train,y_train)
print("Accuracy of the training set: ",model.score(X_train,y_train))
print("Accuracy of the test set: ",model.score(X_test,y_test))
# Out:
# Accuracy of the training set:  1.0
# Accuracy of the test set:  0.958041958041958

# %%
model=RandomForestClassifier(n_estimators=100,max_depth=4,random_state=0,max_features=10 )
model.fit(X_train,y_train)
print("Accuracy of the training set {:.3f} ".format(model.score(X_train,y_train)))
print("Accuracy of the test set {:.3f} ".format(model.score(X_test,y_test)))
# Out:
# Accuracy of the training set 0.988
# Accuracy of the test set 0.958

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Feature Importance:", model.feature_importances_)
# Out:
# Feature Importance: [0.01763405 0.00914741 0.02454025 0.03282881 0.00508565 0.00254375
#  0.01197566 0.10674107 0.00353669 0.00048709 0.0078265  0.0046944
#  0.00344844 0.0181626  0.00285458 0.00157838 0.00257189 0.00137619
#  0.00225328 0.00308909 0.1539725  0.01915632 0.19792338 0.11951124
#  0.00856711 0.0119075  0.0137738  0.20209547 0.00558604 0.00513086]

# %%
n_features = cancer.data.shape[1]

plt.barh(range(n_features), model.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.show()
