# %% [markdown]
# <a href="https://colab.research.google.com/github/rufoabrahamguyo/Library-Management-System/blob/main/wk9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# Load the dataset
cancer = load_breast_cancer()

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=42)

# Train a pre-pruned Decision Tree
tree_model = DecisionTreeClassifier(max_depth=4, random_state=42)
tree_model.fit(X_train, y_train)

# Print training and test accuracy
print("Accuracy of training set: {:.2f}".format(tree_model.score(X_train, y_train)))
print("Accuracy of test set: {:.2f}".format(tree_model.score(X_test, y_test)))

# Plot the decision tree
plt.figure(figsize=(20, 10))  # Make it large and readable
plot_tree(
    tree_model,
    filled=True,
    rounded=True,
    class_names=cancer.target_names,
    feature_names=cancer.feature_names
)
plt.title("Decision Tree (max_depth=4) on Breast Cancer Dataset")
plt.show()
# Out:
# Accuracy of training set: 0.99
# Accuracy of test set: 0.94

# %%
print("Feature importances:",tree_model.feature_importances_)
# Out:
# Feature importances: [0.         0.02700566 0.         0.         0.         0.
#  0.         0.04503514 0.         0.         0.         0.
#  0.         0.0166988  0.         0.         0.         0.
#  0.         0.01488647 0.00697803 0.03307602 0.72543275 0.01882309
#  0.         0.         0.         0.11206403 0.         0.        ]

# %%
n_features = cancer.data.shape[1]
plt.barh(range(n_features), tree_model.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
# Out:
# Text(0, 0.5, 'Features')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define class probabilities for a binary classification (p and 1-p)
x= np.linspace(0, 1, 100)
y = 1 - (x**2 + (1 - x)**2)

# Plotting the Gini impurity
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$Gini = 1 - \sum p_i^2$', color='purple')
plt.xlabel("Class Probability p")
plt.ylabel("Gini Impurity")
plt.title("Gini Impurity for Binary Classification")
plt.grid(True)
plt.legend()
plt.show()
